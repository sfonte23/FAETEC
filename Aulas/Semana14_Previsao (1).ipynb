# %% [markdown]
# # Semana 14 - Previsão (parte 2)
#
# Nesta semana, você aprenderá sobre a importância da antecipação no mercado financeiro, permitindo tomar decisões informadas em investimentos, gerenciar riscos e identificar oportunidades. Também explorará modelos quantitativos e séries temporais para análises financeiras. Através de exemplos práticos, como previsão cambial e de ações, você desenvolverá habilidades essenciais para navegar no mundo financeiro complexo e tomar decisões mais inteligentes.

# %% [markdown]
# ---
#
# ## Antecipação no Mercado Financeiro
#
# ⏲️ A antecipação desempenha um papel crucial no mercado financeiro e é fundamental para a tomada de decisões informadas e bem-sucedidas. Aqui estão algumas das principais razões pelas quais a antecipação é importante no mercado financeiro:

# %% [markdown]
# 1. **Tomada de Decisões Informadas**: Antecipar eventos econômicos, políticos e outros fatores que afetam os mercados financeiros permite que os investidores e traders tomem decisões mais informadas. Isso inclui a previsão de mudanças nas taxas de juros, indicadores econômicos, resultados de empresas e eventos geopolíticos que podem impactar os preços dos ativos.
#
# 2. **Gerenciamento de Risco**: A antecipação ajuda a gerenciar o risco financeiro. Ao prever possíveis eventos adversos, os investidores podem ajustar suas carteiras de investimento, implementar estratégias de hedge e adotar medidas preventivas para proteger seu capital.
#
# 3. **Oportunidades de Investimento**: Antecipar tendências de mercado e identificar oportunidades antes que se tornem amplamente reconhecidas pode ser lucrativo. Os investidores que antecipam a próxima grande tendência ou oportunidade de investimento podem capitalizar antes que os preços subam.
#
# 4. **Redução de Volatilidade**: A antecipação permite uma melhor gestão da volatilidade. Quando os investidores estão preparados para eventos potencialmente voláteis, eles são menos propensos a reagir impulsivamente a notícias inesperadas e a tomar decisões precipitadas.
#
# 5. **Planejamento Financeiro**: Antecipar eventos futuros, como aposentadoria, despesas importantes ou mudanças nas circunstâncias pessoais, é essencial para o planejamento financeiro a longo prazo. Isso ajuda a construir reservas financeiras adequadas e a desenvolver estratégias de investimento que estejam alinhadas com os objetivos individuais.
#
# 6. **Competição no Mercado**: No mercado financeiro, a antecipação muitas vezes implica estar à frente da concorrência. Os traders e gestores de ativos que podem antecipar eventos e reagir rapidamente têm uma vantagem competitiva significativa.
#
# 7. **Criação de Valor**: A antecipação pode criar valor. Quando os investidores antecipam o crescimento de uma empresa ou setor, eles podem investir nesse potencial antes que os preços dos ativos subam, o que pode resultar em lucros substanciais.
#
# 8. **Compliance Regulatório**: Antecipar mudanças regulatórias é fundamental para as empresas financeiras. Isso permite que elas se adaptem às novas regras e evitem potenciais penalizações ou problemas legais.
#
# 9. **Gestão de Portfólio**: Investidores institucionais e individuais frequentemente usam a antecipação para ajustar suas alocações de ativos e estratégias de investimento. Isso ajuda a otimizar o desempenho do portfólio e a manter uma abordagem equilibrada.
#
# > Em resumo, a antecipação desempenha um papel central no mercado financeiro, pois permite que os participantes se preparem para o futuro, tomem decisões mais informadas, gerenciem o risco e identifiquem oportunidades de investimento. A capacidade de antecipar eventos e tendências é uma habilidade valiosa para investidores, traders, gestores de ativos e qualquer pessoa envolvida no mundo das finanças.
#
# ---

# %% [markdown]
# ## Modelos Quantitativos
#
# 📥 A antecipação no mercado financeiro envolve a coleta e análise de informações relevantes para prever eventos futuros que possam afetar os preços dos ativos, as taxas de juros, as condições econômicas e outros fatores financeiros. Existem várias formas de fazer essa antecipação.
#
# 🧮 Dentre elas, os **modelos quantitativos** desempenham um papel fundamental na tomada de decisões financeiras informadas, permitindo que investidores e instituições financeiras aproveitem dados e análises matemáticas avançadas para tomar decisões de investimento, gerenciar riscos e identificar oportunidades nos mercados financeiros.
#
# > _É importante notar que esses modelos não são infalíveis e estão sujeitos a erros e incertezas inerentes aos mercados financeiros. Portanto, é crucial combinar análises quantitativas com julgamento humano e considerações qualitativas._
#
# ### Séries Temporais
#
# 📈 Os modelos quantitativos utilizados no mercado financeiro têm um grau de dificuldade mais elevado pois grande parte das análises são realizadas em **séries temporais**:
#
# >  _As séries temporais são conjuntos de dados organizados em uma ordem cronológica específica, onde cada ponto de dado está associado a um momento no tempo. Esta classe de dados é utilizada para entender como os dados mudam ao longo do tempo, identificar tendências, padrões sazonais e eventos anômalos._
# >
# > _**Exemplo:** uma série temporal pode ser usada para acompanhar o preço das ações de uma empresa ao longo dos meses ou anos. Isso permite a análise de como o preço das ações flutua com o tempo e a tentativa de prever seu comportamento futuro com base nos dados históricos._
#
# ---

# %% [markdown]
# ## Aplicações

# %% [markdown]
# > 🛠️ *Exemplo prático 1:* Prevendo ações bancárias utilizando informações de ações adicionais.
#
# *  Na Semana 08, vimos como algumas ações bancárias evoluem ao longo do tempo de forma parecida através dos gráficos de linhas e de dispersão.
# *  Na Semana 11, vimos o conceito da métrica estatística chamada correlação linear.
# *  Na Semana 13, aprendemos a fazer previsões para o futuro utilizando apenas a informação da própria variável.
#
# 👉 Agora, iremos abordar um exemplo que engloba todos esses conceitos:

# %%
# Carregando pacotes
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet

# %%
# Definindo abreviação (ticker)
bancos_tickers = ["BBAS3.SA",   # Banco do Brasil
                  "BBDC4.SA",   # Bradesco
                  "ITUB4.SA",   # Itau
                  "SANB11.SA"]  # Santander

# Obtendo dados
df_bancos = yf.download(bancos_tickers,       # Ações
                        start="2023-01-01",   # Data inicial AAAA-MM-DD
                        end="2023-09-01",     # Data final AAAA-MM-DD
                        progress = False).dropna()

# Selecionando as colunas `Adj Close` pela posição
df_bancos = df_bancos.iloc[:, [0, 1, 2, 3]]

# Renomeando colunas
df_bancos.columns = bancos_tickers

# Criando o gráfico
df_bancos.plot()

# Adicionando:
plt.title('Valores de fechamento') # Título
plt.xlabel('Data')                 # Rótulo do eixo horizontal (x)
plt.ylabel('Valor (R$)')           # Rótulo do eixo vertical (y)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# 💬 Relembre como as ações bancárias aparentam evoluir de forma semelhante, embora tenha médias e variabilidade distintas.
#
# 👉 Vamos fazer previsões para `BBAS3.SA`. Para isso, precisamos saber quão correlacionadas estão as demais variáveis com a ação em questão.

# %%
# Matriz de correlação
df_bancos.corr()
# Out:
#            BBAS3.SA  BBDC4.SA  ITUB4.SA  SANB11.SA
# BBAS3.SA   1.000000  0.815642  0.905060   0.567685
# BBDC4.SA   0.815642  1.000000  0.918076   0.811794
# ITUB4.SA   0.905060  0.918076  1.000000   0.771456
# SANB11.SA  0.567685  0.811794  0.771456   1.000000

# %% [markdown]
# 💬 Vamos analisar a primeira coluna que é a relacionada à `BBAS3.SA`:
# *  Valores positivos acima de 0,6 implicam em uma correlação notável. Ou seja, em grande parte das vezes, quando as demais ações sobem, `BBAS3.SA` também sobe de forma linear.
#
# * Por isso os pontos formam uma nuvem quase linear no gráfico abaixo:

# %%
# Criando o gráfico
pd.plotting.scatter_matrix(df_bancos)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Coeficiente de determinação
#
# O coeficiente de determinação, também conhecido como R², é uma medida que determina o quanto a variação de uma variável é explicada pela outra.
#
# O R² varia entre 0 e 1, por vezes sendo expresso em termos percentuais. Quanto maior, mais uma variável explica a outra.

# %%
# Calculando o R2
# > Basta elevar a matriz de correlação ao quadrado:
r2 = df_bancos.corr() ** 2
r2
# Out:
#            BBAS3.SA  BBDC4.SA  ITUB4.SA  SANB11.SA
# BBAS3.SA   1.000000  0.665273  0.819133   0.322266
# BBDC4.SA   0.665273  1.000000  0.842863   0.659010
# ITUB4.SA   0.819133  0.842863  1.000000   0.595144
# SANB11.SA  0.322266  0.659010  0.595144   1.000000

# %% [markdown]
# > ⚠️ **INTERPRETANDO**
# >
# > * `BBDC4.SA` explica **individualmente** 57,53% da variação de `BBAS3.SA`
# >
# > *  `ITUB4.SA` explica **individualmente** 74,41% da variação de `BBAS3.SA`
# >
# > *  `SANB11.SA` explica **individualmente** 42,73% da variação de `BBAS3.SA`
#
# > ⛔ Estes valores são individuais!
# > *  Se utilizarmos as 3 ações `BBDC4.SA`, `ITUB4.SA` e `SANB11.SA` simultaneamente para explicar `BBAS3.SA`, os percentuais **NÃO** são somados e a conta se torna bem mais complicada!

# %% [markdown]
# 👉 Vamos preparar os dados

# %%
# Obrigatoriamente, devemos chamar o que queremos prever de 'y'
# e as datas de 'ds'
# As demais variaveis podem ter qualquer nome
df_bancos = df_bancos.reset_index()
df_bancos.columns = ['ds', 'y', 'BBDC4.SA', 'ITUB4.SA', 'SANB11.SA']
df_bancos

# %%
# Numero de períodos que quero fazer previsão
periodo = 30

# DataFrame de treino
df_treino = df_bancos.iloc[:-periodo]

# DataFrame de teste
df_teste = df_bancos.iloc[-periodo:]

# %% [markdown]
# 👉 Vamos adicionar `BBDC4.SA`, `ITUB4.SA`, `SANB11.SA` como informação adicional para prever valores da ação `BBAS3.SA`.
#
# > No `prophet`, estas variáveis são chamadas de _regressoras_

# %%
# Criando o modelo
modelo = Prophet()

# Lista de nomes das variáveis regressoras
var_regressoras = ['BBDC4.SA', 'ITUB4.SA', 'SANB11.SA']

# Adicionando variáveis regressoras usando um loop
for var in var_regressoras:
    modelo.add_regressor(var)

# Estimando o modelo
modelo.fit(df_treino)

# %% [markdown]
# 👉 Agora, vamos fazer previsões!

# %%
# Previsões para dados de treino (passado)
previsoes_treino = modelo.predict(df_treino)

# %% [markdown]
# ⚠️ Relembre que o DataFrame `teste` está relacionado ao futuro!
#
# Nele, estão contidos valores futuros de `BBDC4.SA`, `ITUB4.SA`, `SANB11.SA`.
#
# 👉 Na prática, não conhecemos esses valores ainda! Então, vamos prevê-los usando novamente o `Prophet`.

# %%
# Para facilitar, vamos criar uma função
# para repetir mais facilmente os procedimentos

def previsao_func(regressoras,  # Variaveis regressoras
                  teste,        # DF de teste
                  periodo       # Periodo de previsao
                  ):

  res = teste.copy()

  for var in regressoras:
    df = res.loc[:, ['ds', var]]
    df.columns = ['ds', 'y']
    df

    # Criando o modelo
    modelo0 = Prophet()

    # Estimando o modelo
    modelo0.fit(df)

    # Previsões para dados de teste (futuro)
    res.loc[:,var] = modelo0.predict(df)['yhat'].tolist()

  return res

# %% [markdown]
# 👉 Para efeito de comparação, vamos ver o que mudou entre o ocorrido (futuro) e as previsões feitas:

# %%
# Observado (no futuro - que não conhecemos no momento)
df_teste_ANTIGA = df_teste.copy()

# Previsão para este futuro (somente as regressoras)
df_teste = previsao_func(regressoras = var_regressoras,
              teste = df_teste,
              periodo = periodo).copy()

# %%
df_teste_ANTIGA.head()
# Out:
#             ds          y   BBDC4.SA   ITUB4.SA  SANB11.SA
# 137 2023-07-21  47.501045  16.996048  28.661346  29.558489
# 138 2023-07-24  46.570995  16.537773  28.206722  29.331951
# 139 2023-07-25  46.326244  16.477999  28.266020  29.006916
# 140 2023-07-26  46.717846  16.647360  28.424150  28.908419
# 141 2023-07-27  45.758427  16.268785  27.791626  27.972712

# %%
df_teste.head()
# Out:
#             ds          y   BBDC4.SA   ITUB4.SA  SANB11.SA
# 137 2023-07-21  47.501045  16.846712  28.448132  29.453606
# 138 2023-07-24  46.570995  16.738826  28.363878  29.160450
# 139 2023-07-25  46.326244  16.758257  28.475799  29.103067
# 140 2023-07-26  46.717846  16.719750  28.415041  28.846876
# 141 2023-07-27  45.758427  16.502695  28.131061  28.416332

# %% [markdown]
# 💬 Note que substituimos `BBDC4.SA`, `ITUB4.SA`, `SANB11.SA` por suas previsões. `ds`e `y` se mantem identicos.

# %% [markdown]
# 👉 Agora, vamos podemos fazer as previsões conjuntas (pro futuro)!

# %%
# Previsões para dados de teste (futuro)
# Utilizando as previsões individuais de
# BBDC4.SA, ITUB4.SA, SANB11.SA
previsoes_teste = modelo.predict(df_teste)

# %% [markdown]
# 👁️‍🗨️ Visualizando o resultado:

# %%
# Dados de treino
plt.plot(df_treino['ds'], df_treino['y'], '.-',
         color='tab:grey', label='Dados de treino')

# Dados de teste
plt.plot(df_teste['ds'], df_teste['y'], '.-',
         color='black', label='Dados de teste')

# Previsão (treino)
plt.plot(df_treino['ds'], previsoes_treino['yhat'], '--',
         color='goldenrod', label='Previsão (treino)')

# Previsão (teste)
plt.plot(df_teste['ds'], previsoes_teste['yhat'],
         color='goldenrod', label='Previsão (teste)', linewidth=2.0)

# Incerteza (teste)
plt.fill_between(df_teste['ds'], previsoes_teste['yhat_lower'],
                 previsoes_teste['yhat_upper'],
                 color='goldenrod', alpha=0.25, label='Incerteza')

# Rótulos
plt.title('Previsão: Preço da ação BBAS3.SA')
plt.xlabel('Data')
plt.ylabel('Valor (R$)')

# Legenda
plt.legend(loc='upper left') # local: esquerda superior

# Rotacionando a data no eixo horizontal 90 graus
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# 💬 Note que o modelo se adequa melhor quando fornecemos mais informações à ele. Diferente da aula anterior, a incerteza cresce lentamente ao passar do tempo. Isso também está associado ao acrescimo de informações.
#
# ⚠️ Prever ações é muito difícil! Mas ainda assim, estamos mandando muito bem aqui!

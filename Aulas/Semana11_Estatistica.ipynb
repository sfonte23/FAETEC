# %% [markdown]
# # Semana 11 - Estatística Descritiva
#
# Nesta semana de estudos, você descobrirá a importância da estatística descritiva no mercado financeiro. A estatística descritiva é essencial para compreender e interpretar dados financeiros de maneira eficaz. Você aprenderá como ela organiza dados em tabelas, gráficos e medidas como médias, medianas e desvios padrão. Além disso, explorará como a estatística descritiva identifica tendências, padrões e sazonalidades nos preços de ativos e indicadores econômicos, fornecendo informações valiosas para decisões informadas no mercado financeiro. A semana de estudos abordará temas como avaliação de risco, comparação de investimentos, construção de portfólios e análise de desempenho de fundos e gestores. Compreender e aplicar a estatística descritiva o ajudará a tomar decisões mais informadas sobre alocação de ativos, monitoramento de eventos econômicos e avaliação de riscos de crédito, contribuindo para o sucesso e eficiência em suas operações financeiras.

# %% [markdown]
# ---
#
#
#
# ## Estatística Descritiva no Mercado Financeiro
#
# 📋 A estatística descritiva desempenha um papel fundamental nas análises do mercado financeiro, sendo uma ferramenta indispensável para investidores, analistas e tomadores de decisão. Essa disciplina estatística permite que os profissionais financeiros compreendam, interpretem e comuniquem dados financeiros de maneira eficaz, fornecendo insights valiosos para a tomada de decisões informadas. Aqui estão algumas das razões pelas quais a estatística descritiva é importante no contexto do mercado financeiro:

# %% [markdown]
# 1.	**Resumo e Organização de Dados**: A estatística descritiva ajuda a resumir grandes conjuntos de dados financeiros, tornando-os mais compreensíveis. Ela permite a organização dos dados em tabelas, gráficos e medidas de resumo, como médias, medianas e desvios padrão.
#
# 2.	**Identificação de Tendências e Padrões**: Ao analisar séries temporais de preços de ativos ou indicadores econômicos, a estatística descritiva ajuda a identificar tendências, sazonalidades e padrões que podem ser usados para tomar decisões de investimento informadas.
#
# 3.	**Medição de Risco**: A estatística descritiva é essencial para a avaliação de risco no mercado financeiro. O cálculo de medidas de volatilidade, como o desvio padrão, ajuda os investidores a entender o grau de variação nos preços dos ativos e a gerenciar seus riscos.
#
# 4.	**Comparação de Investimentos**: Investidores frequentemente precisam comparar o desempenho de diferentes ativos financeiros, como ações, títulos ou fundos mútuos. A estatística descritiva fornece ferramentas para realizar essas comparações de maneira objetiva.
#
# 5.	**Tomada de Decisões Informadas**: Com base nas análises estatísticas descritivas, os investidores podem tomar decisões informadas sobre a alocação de ativos, a construção de portfólios e a seleção de estratégias de investimento.
#
# 6.	**Avaliação de Desempenho de Fundos e Gestores**: Para avaliar o desempenho de fundos de investimento e gestores de carteira, a estatística descritiva é usada para calcular indicadores que medem o retorno ajustado pelo risco.
#
# 7.	**Compreensão da Distribuição de Retornos**: A estatística descritiva ajuda a entender a distribuição de retornos de ativos financeiros, o que é crucial para a modelagem de riscos e a elaboração de estratégias de gerenciamento de portfólio.
#
# 8.	**Monitoramento de Eventos Econômicos**: A análise de dados econômicos, como taxas de juros, inflação e indicadores de mercado de trabalho, por meio de técnicas estatísticas descritivas, permite aos investidores antecipar eventos econômicos e suas implicações nos mercados financeiros.
#
# 9.	**Relatórios Financeiros**: Empresas e instituições financeiras usam estatísticas descritivas para apresentar seus resultados financeiros de forma clara e concisa em relatórios, tornando-os acessíveis aos investidores e reguladores.
#
# 10.	**Avaliação de Riscos de Crédito**: A estatística descritiva é crucial para avaliar o risco de crédito ao analisar o histórico de pagamentos de devedores e calcular métricas como o rating de crédito.
#
# > Em resumo, a estatística descritiva desempenha um papel essencial nas análises do mercado financeiro, fornecendo as ferramentas necessárias para resumir, analisar e interpretar dados financeiros. Ela ajuda os investidores e analistas a compreenderem os mercados, identificar tendências, gerenciar riscos e avaliar o desempenho de investimentos. Sem ela, a tomada de decisões informadas no mundo financeiro seria muito mais desafiadora e arriscada. Portanto, a estatística descritiva é uma aliada indispensável para quem busca sucesso e eficiência nas operações financeiras.
#
# ---

# %% [markdown]
# ## Medidas de posição
#
# 🔛 As medidas de posição são ferramentas estatísticas fundamentais que nos ajudam a entender a distribuição dos dados em um conjunto de informações. Elas fornecem *insights* valiosos sobre onde os valores estão centralizados.

# %% [markdown]
# ### Média
#
# 🔣 É a medida de posição mais conhecida e amplamente usada. Ela é calculada somando todos os valores de um conjunto de dados e dividindo o resultado pelo número de observações:

# %%
# Carregando pacotes
import pandas as pd

# Dados ficticios
dados = pd.Series([8, 6, 5, 7, 3, 2])

# Calculando a média manualmente:
# 1) somando todos os valores de um conjunto de dados
#    8 + 6 + 5 + 7 + 3 + 2
# 2) dividindo o resultado pelo número de observações
#    / 6
media = (8 + 6 + 5 + 7 + 3 + 2) / 6
print(f'Média: {media}')

# Calculando a média de um objeto pd.Series ou pd.DataFrame
print(f'Média: {dados.mean()}')
# Out:
# Média: 5.166666666666667
# Média: 5.166666666666667

# %% [markdown]
# ---
#
# > 🛠️ *Exemplo prático 1:* Calculando medidas de posição para determinadas ações

# %%
# Carregando pacotes
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Definindo abreviação (ticker)
ticker = ["PETR4.SA", "ELET3.SA"]

# Obtendo dados
df_acao = yf.download(ticker,                # Ação
                      start="2023-01-01",    # Data inicial AAAA-MM-DD
                      end="2023-04-01",      # Data final AAAA-MM-DD
                      progress=False)

# Selecionando a coluna `Adj Close` pela posição
df_acao = df_acao.iloc[:, [0, 1]]

# Renomeando coluna
df_acao.columns = ["ELET3.SA", "PETR4.SA"]

# Visualizando resultado
df_acao
# Out:
#              ELET3.SA   PETR4.SA
# Date
# 2023-01-02  40.327332  18.442507
# 2023-01-03  39.572250  17.975815
# 2023-01-04  40.635326  18.547113
# 2023-01-05  40.714806  19.214970
# 2023-01-06  40.734676  19.102320
# ...               ...        ...
# 2023-03-27  31.693565  18.651718
# 2023-03-28  33.273277  18.981623
# 2023-03-29  32.975216  19.231062
# 2023-03-30  33.680626  19.287388
# 2023-03-31  33.064636  18.868971
#
# [63 rows x 2 columns]

# %% [markdown]
# 👉 Calculando medidas de posição para as ações listadas durante o intervalo de tempo estabelecido:

# %%
# Calculando medidas de posição: Média
medias = df_acao.mean()
medias
# Out:
# ELET3.SA    36.447680
# PETR4.SA    20.056656
# dtype: float64

# %% [markdown]
# 👉 Adicionando estas medidas em um gráfico de linha:

# %%
# Criando o gráfico
df_acao.plot(color=['goldenrod', 'darkgreen'])

# Adicionando:
plt.title('Valores de fechamento: 1o Trimestre / 2023') # Título
plt.xlabel('Data')                 # Rótulo do eixo horizontal (x)
plt.ylabel('Valor (R$)')           # Rótulo do eixo vertical (y)

# Adicionando linhas horizontais representando as:
# Médias
plt.axhline(y=medias['ELET3.SA'], color='goldenrod', linestyle='dashed')
plt.axhline(y=medias['PETR4.SA'], color='darkgreen', linestyle='dashed')

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Média móvel
#
# 🔣 É uma ferramenta valiosa para suavizar dados, identificar tendências, fazer previsões e tomar decisões informadas em uma variedade de campos, especialmente quando se lida com séries temporais ou conjuntos de dados que exibem variações ao longo do tempo.

# %% [markdown]
# > 🛠️ *Exemplo prático 2:* Calculando médias móveis para determinadas ações
# >  * Calcular medidas de dispersão por um período muito longo de tempo pode levar a índices enviesados

# %%
# Definindo abreviação (ticker)
ticker = ["BBAS3.SA", # Banco do Brasil
          "BBDC4.SA", # Bradesco
          "ITUB4.SA"] # Itau

# Obtendo dados
df_acao = yf.download(ticker,                # Ação
                      start="2014-01-01",    # Data inicial AAAA-MM-DD
                      end="2023-04-01",      # Data final AAAA-MM-DD
                      progress=False)

# Selecionando a coluna `Adj Close` pela posição
df_acao = df_acao.iloc[:, [0, 1, 2]]

# Renomeando coluna
df_acao.columns = ticker

# Visualizando resultado
df_acao
# Out:
#              BBAS3.SA   BBDC4.SA   ITUB4.SA
# Date
# 2014-01-02  13.227495   7.125973  10.425650
# 2014-01-03  13.365273   7.098684  10.405803
# 2014-01-06  13.166870   7.158233  10.422340
# 2014-01-07  12.940899   7.001919  10.342960
# 2014-01-08  12.681861   6.996953  10.505032
# ...               ...        ...        ...
# 2023-03-27  36.289204  12.688601  23.311222
# 2023-03-28  36.540070  12.668989  23.419781
# 2023-03-29  36.964622  12.737628  23.646774
# 2023-03-30  37.640038  13.120053  24.298147
# 2023-03-31  37.736523  12.914132  24.416576
#
# [2299 rows x 3 columns]

# %% [markdown]
# 👉 Calculando a média móvel das ações
# *   É necessário definir um périodo retroativo para se calcular a média móvel.
# *   Como estamos tratando de dados diários, podemos considerar 5 (5 dias úteis = 1 semana, por exemplo)

# %%
# Iniciando um DataFrame vazio
media_movel = pd.DataFrame()

# Calcular a média móvel de 5 períodos
media_movel['BBAS3.SA_MM'] = df_acao['BBAS3.SA'].rolling(5).mean()
media_movel['BBDC4.SA_MM'] = df_acao['BBDC4.SA'].rolling(5).mean()
media_movel['ITUB4.SA_MM'] = df_acao['ITUB4.SA'].rolling(5).mean()
media_movel
# Out:
#             BBAS3.SA_MM  BBDC4.SA_MM  ITUB4.SA_MM
# Date
# 2014-01-02          NaN          NaN          NaN
# 2014-01-03          NaN          NaN          NaN
# 2014-01-06          NaN          NaN          NaN
# 2014-01-07          NaN          NaN          NaN
# 2014-01-08    13.076480     7.076353    10.420357
# ...                 ...          ...          ...
# 2023-03-27    36.194643    12.625844    23.056407
# 2023-03-28    36.260255    12.582699    23.080145
# 2023-03-29    36.393410    12.576815    23.176603
# 2023-03-30    36.740768    12.735668    23.518475
# 2023-03-31    37.034091    12.825881    23.818500
#
# [2299 rows x 3 columns]

# %% [markdown]
# 💬 Note que os primeiro períodos possuem `NaN`. Ou seja, não temos informação pois utilizamos estes valores para calcular as médias a frente!

# %%
# Criando o gráfico
df_acao.plot(color=['goldenrod', 'firebrick', 'coral'])

# Adicionando:
plt.title('Valores de fechamento: 2014/T1 a 2023/T1') # Título
plt.xlabel('Data')                 # Rótulo do eixo horizontal (x)
plt.ylabel('Valor (R$)')           # Rótulo do eixo vertical (y)

# Adicionando as médias móveis
plt.plot(media_movel.index.to_numpy(),
         media_movel['BBAS3.SA_MM'],
         color='black',  # Cor = preto
         linewidth=.5,   # Largura reduzida
         linestyle='dashed') # Linha tracejada

plt.plot(media_movel.index.to_numpy(),
         media_movel['BBDC4.SA_MM'],
         color='black',  # Cor = preto
         linewidth=.5,   # Largura reduzida
         linestyle='dashed') # Linha tracejada

plt.plot(media_movel.index.to_numpy(),
         media_movel['ITUB4.SA_MM'],
         color='black',  # Cor = preto
         linewidth=.5,   # Largura reduzida
         linestyle='dashed') # Linha tracejada

# Exibindo o gráfico
plt.show()

# %% [markdown]
# 💬 Note que as médias móveis são mais suaves e contém menos movimentos bruscos.
#
# *    👁️‍🗨️ A partir deste método, já conseguimos fazer previsões: A partir das últimas 5 cotações, podemos predizer o valor da ação para o próximo dia!

# %%
# Recuperando os 5 últimos valores
df_acao['BBAS3.SA'].tail(5)
# Out:
# Date
# 2023-03-27    36.289204
# 2023-03-28    36.540070
# 2023-03-29    36.964622
# 2023-03-30    37.640038
# 2023-03-31    37.736523
# Name: BBAS3.SA, dtype: float64

# %%
# Uma possível previsão para o próximo dia útil (03/04/2023) seria:
previsao_mm = df_acao['BBAS3.SA'].tail(5).mean()
print(f'BBAS3.SA | Previsão para 03/04/2023: R${round(previsao_mm, 2)}')
# Out:
# BBAS3.SA | Previsão para 03/04/2023: R$37.03

# %%
# Qual foi o valor observado nesta data?
valor_verdadeiro = (yf.
                    download('BBAS3.SA',
                             start="2023-04-03",
                             end="2023-04-04",
                             progress=False).
                    reset_index().
                    loc[:, ['Adj Close']])

print(f'BBAS3.SA | Valor para 03/04/2023: R${round(valor_verdadeiro.iloc[0, 0], 2)}')
# Out:
# BBAS3.SA | Valor para 03/04/2023: R$37.29

# %% [markdown]
# > 🔎 Para você, a previsão foi satisfatória?
#
# ---

# %% [markdown]
# ## Medidas de dispersão
#
# 🔛 Medidas de dispersão são componentes cruciais que nos ajudam a compreender a extensão com a qual os valores em um conjunto de dados se afastam da medida de tendência central, como a média. Elas fornecem *insights* importantes sobre a variabilidade e a distribuição dos dados. As medidas de dispersão mais comuns são:

# %% [markdown]
# ### Variância
#
# 🔣 É uma medida que quantifica a dispersão dos dados em relação à média. Ela é calculada ao encontrar a média dos quadrados das diferenças entre cada valor e a média do conjunto de dados:

# %%
# Dados ficticios
dados = pd.Series([8, 6, 5, 7, 3, 2])

# Calculando a variância de um objeto pd.Series ou pd.DataFrame
print(f'Variância: {dados.var()}')
# Out:
# Variância: 5.366666666666667

# %% [markdown]
# > ⚠️ **ALGUMAS OBSERVAÇÕES SOBRE A VARIÂNCIA**
# >
# > A variância:
# > * alta indica que os valores do conjunto de dados estão amplamente dispersos em relação à média
# > * baixa sugere que os valores estão mais próximos da média.
# > * nula implica que os valores são todos iguais.
# > * é sempre maior ou igual à zero.
# > * é uma medida com escala quadrática. Se os dados se referem à valores (R\$), a variância está em uma medida de valores ao quadrado (R\$ $^2$), difícil de interpretar.

# %% [markdown]
# ### Desvio-Padrão
#
# 🔣 É a raiz quadrada da variância e é uma medida de dispersão mais utilizada e interpretável pois tem as mesmas unidades originais dos dados, o que o torna mais intuitivo para a compreensão da dispersão.

# %%
# Dados ficticios
dados = pd.Series([8, 6, 5, 7, 3, 2])

# Calculando o desvio-padrão de um objeto pd.Series ou pd.DataFrame
print(f'Desvio-padrão: {dados.std()}')

# Demonstrando que desvio padrao = raiz quadrada da variancia
print(f'Desvio-padrão: {dados.var() ** (1/2)}')
# Out:
# Desvio-padrão: 2.316606713852541
# Desvio-padrão: 2.316606713852541

# %% [markdown]
# > ⚠️ Quanto maior o desvio-padrão, maior a dispersão dos dados em relação à média, e vice-versa (assim como na variância).
#
# ---

# %% [markdown]
# ## Volatilidade
#
# 〽️ A volatilidade no mercado financeiro se refere à medida da variação dos preços de ativos financeiros, como ações, títulos, moedas e commodities, ao longo do tempo. Ela descreve a magnitude das flutuações de preço e a incerteza associada aos movimentos desses ativos. A volatilidade é uma parte intrínseca dos mercados financeiros e desempenha um papel crucial na tomada de decisões de investimento e gestão de riscos. Alguns pontos importantes sobre a volatilidade:
#
# 1.   **Natureza Inerente**: A volatilidade é uma característica natural dos mercados financeiros. Os preços dos ativos podem ser influenciados por uma ampla gama de fatores, como notícias econômicas, eventos políticos, mudanças nas taxas de juros, condições macroeconômicas e sentimentos do mercado. Esses fatores, por sua natureza imprevisível, contribuem para a volatilidade dos preços.
#
# 2.   **Medição**: A volatilidade é frequentemente medida usando indicadores estatísticos, sendo o mais comum deles o desvio-padrão ou a variância dos retornos de um ativo. Quanto maior for o desvio-padrão, maior a volatilidade.
#
# 3.   **Impacto nos Investimentos**: A volatilidade afeta diretamente a rentabilidade e o risco dos investimentos. Ativos mais voláteis têm o potencial de gerar retornos significativamente mais altos, mas também apresentam riscos substanciais de perdas. Investidores geralmente consideram a volatilidade ao escolher ativos para suas carteiras e ao ajustar a alocação de ativos de acordo com seus objetivos e tolerância ao risco.
#
# 4.    **Estratégias de Negociação**: *Traders* e investidores utilizam estratégias específicas para aproveitar a volatilidade do mercado. Por exemplo, o *day trading* é uma abordagem em que os *traders* aproveitam as flutuações de curto prazo para lucrar. Da mesma forma, existem produtos financeiros, como opções e contratos futuros, projetados para ajudar os investidores a proteger ou alavancar suas posições em resposta à volatilidade.
#
# 5.    **Gestão de Riscos**: A volatilidade é um componente crítico na gestão de riscos financeiros. Empresas, investidores institucionais e indivíduos usam estratégias de gerenciamento de riscos, como a diversificação de carteiras e o uso de derivativos, para proteger seus investimentos contra movimentos de preços adversos.
#
# 6.    **Indicador Econômico**: A volatilidade também é usada como um indicador econômico. Em geral, mercados financeiros mais voláteis podem refletir incertezas na economia global. Os analistas observam a volatilidade como um sinal de possíveis mudanças no ambiente econômico e político.
#
# > Em resumo, a volatilidade é uma característica inerente aos mercados financeiros que descreve a magnitude das flutuações de preço ao longo do tempo. Ela é fundamental para a tomada de decisões de investimento, a gestão de riscos e a compreensão das condições econômicas e de mercado. Investidores e traders precisam considerar a volatilidade ao tomar decisões informadas sobre como alocar seus recursos e quais estratégias adotar.

# %% [markdown]
# ---
#
# > 🛠️ *Exemplo prático 3:* Calculando a volatilidade para diferentes moedas

# %%
# Definindo abreviação (ticker)
ticker = ["BRL=X", # Real (Brasil)
          "CAD=X", # Dólar canadense (Canadá)
          "CHF=X", # Franco suíço (Suíça)
          "GBPUSD=X"] # Libra esterlina (Reino Unido)

# Obtendo dados
df_cambio = yf.download(ticker,                # Moedas
                        start="2023-01-01",    # Data inicial AAAA-MM-DD
                        end="2023-04-01",      # Data final AAAA-MM-DD
                        progress=False)

# Selecionando a coluna `Adj Close` pela posição
df_cambio = df_cambio.iloc[:, [0, 1, 2, 3]]

# Renomeando coluna
df_cambio.columns = ["BRL", "CAD", "CHF", "GBP"]

# Visualizando resultado
df_cambio
# Out:
#                  BRL      CAD      CHF       GBP
# Date
# 2023-01-02  5.285500  1.35281  0.92380  1.212033
# 2023-01-03  5.360131  1.35590  0.92400  1.206287
# 2023-01-04  5.478500  1.36741  0.93580  1.196974
# 2023-01-05  5.430100  1.34851  0.92959  1.205705
# 2023-01-06  5.349800  1.35599  0.93583  1.191228
# ...              ...      ...      ...       ...
# 2023-03-27  5.245100  1.37274  0.91990  1.224600
# 2023-03-28  5.197100  1.36541  0.91502  1.229755
# 2023-03-29  5.164400  1.35933  0.92040  1.233046
# 2023-03-30  5.134200  1.35631  0.91810  1.231360
# 2023-03-31  5.092700  1.35219  0.91338  1.238728
#
# [65 rows x 4 columns]

# %% [markdown]
# 👉 Calculando volatilidade para as moedas:

# %%
# Calculando volatilidade: Desvio-padrão
volatilidade = df_cambio.std()
volatilidade
# Out:
# BRL    0.081761
# CAD    0.014779
# CHF    0.008092
# GBP    0.015194
# dtype: float64

# %% [markdown]
# 👉 Identificando estes valores pelo gráfico:

# %%
# Criando o gráfico
df_cambio.plot(color=['darkgreen', 'tomato',
                      'red', 'royalblue'])

# Adicionando:
plt.title('Câmbio')
plt.xlabel('Data')
plt.ylabel('Valor (moeda corrente)')

# Exibindo o gráfico
plt.show()

# %% [markdown]
# 💬 Note que quanto maior a volatilidade, mais flutuação ocorreu com a moeda

# %% [markdown]
# ---
#
# > 🛠️ *Exemplo prático 4:* Calculando a volatilidade da inflação nos países do BRICS (Fonte: FRED)
# *   Inflação - Brasil: https://fred.stlouisfed.org/series/FPCPITOTLZGBRA
# *   Inflação - Russia: https://fred.stlouisfed.org/series/FPCPITOTLZGRUS
# *   Inflação - Índia: https://fred.stlouisfed.org/series/FPCPITOTLZGIND
# *   Inflação - China: https://fred.stlouisfed.org/series/FPCPITOTLZGCHN
# *   Inflação - África do Sul: https://fred.stlouisfed.org/series/FPCPITOTLZGZAF

# %%
# Carregando pacote
import pandas_datareader.data as web
import datetime

# Definindo código
codigo_fred = ['FPCPITOTLZGBRA', # Inflação - Brasil
               'FPCPITOTLZGRUS', # Inflação - Russia
               'FPCPITOTLZGIND', # Inflação - Índia
               'FPCPITOTLZGCHN', # Inflação - China
               'FPCPITOTLZGZAF'] # Inflação - África do Sul

# Definindo data: datetime.datetime(AAAA, MM, DD)
inicio = datetime.datetime(2000, 1, 1)
fim = datetime.datetime(2021, 1, 1)

# Obtendo dados
df_fred = web.DataReader(codigo_fred, 'fred', inicio, fim)

# Renomeando colunas
df_fred.columns = ['Brasil', 'Russia', 'Índia', 'China', 'África do Sul']
# df_fred.columns

# Resultado (tabela)
df_fred
# Out:
#                Brasil     Russia      Índia     China  África do Sul
# DATE
# 2000-01-01   7.044141  20.798761   4.009436  0.347811       5.338951
# 2001-01-01   6.840359  21.477007   3.779293  0.719126       5.701900
# 2002-01-01   8.450164  15.788731   4.297152 -0.731971       9.494711
# 2003-01-01  14.714920  13.663293   3.805859  1.127603       5.679418
# 2004-01-01   6.597185  10.888616   3.767252  3.824637      -0.692030
# 2005-01-01   6.869537  12.685304   4.246344  1.776414       2.062846
# 2006-01-01   4.183568   9.668655   5.796523  1.649431       3.243908
# 2007-01-01   3.641273   9.007299   6.372881  4.816768       6.177807
# 2008-01-01   5.678594  14.110768   8.349267  5.925251      10.074576
# 2009-01-01   4.888035  11.647330  10.882353 -0.728165       7.215314
# 2010-01-01   5.038727   6.849392  11.989390  3.175325       4.089730
# 2011-01-01   6.636450   8.440465   8.911793  5.553899       4.999267
# ...

# %%
# Calculando volatilidade: Desvio-padrão
volatilidade_BRICS = df_fred.std()
volatilidade_BRICS
# Out:
# Brasil           2.598172
# Russia           5.305182
# Índia            2.644221
# China            1.738150
# África do Sul    2.258315
# dtype: float64

# %%
# Criando o gráfico
df_fred.plot(color=['goldenrod', 'lightgrey',
                      'sandybrown', 'tomato', 'darkgreen'])

# Adicionando:
plt.title('Inflação no BRICS')
plt.xlabel('Data')
plt.ylabel('%')

# Exibindo o gráfico
plt.show()

# %% [markdown]
# 💬 Note que a inflação da China aparenta flutuar menos do que nos demais países.
# *  Exatamente como a volatilidade calculada indica!
#
# ---

# %% [markdown]
# ## Correlação linear
#
# 🔀 É uma medida estatística que descreve o grau de relacionamento linear entre duas variáveis em um conjunto de dados. Ela é usada para determinar se existe uma relação linear entre duas variáveis e, em caso afirmativo, qual é a força e a direção dessa relação.
#
# A correlação linear é frequentemente representada pelo coeficiente de correlação (também chamado de $r$) varia de $-1$ a $1$ e fornece as seguintes informações:
#
# *   **Correlação Positiva ($r > 0$)**: Quando o valor de $r$ está próximo de 1, indica uma correlação positiva forte entre as variáveis. Isso significa que, à medida que uma variável aumenta, a outra também tende a aumentar.
#
# *   **Correlação Negativa ($r < 0$)**: Quando o valor de $r$ está próximo de -1, indica uma correlação negativa forte entre as variáveis. Isso significa que, à medida que uma variável aumenta, a outra tende a diminuir.
#
# *    **Ausência de Correlação ($r = 0$)**: Quando o valor de $r$ está próximo de zero, indica que não há uma relação linear aparente entre as variáveis. No entanto, é importante notar que a ausência de correlação linear não implica necessariamente na ausência de outras relações não lineares.
#
# > ⚠️ **A correlação linear só mede relacionamentos lineares entre variáveis**. Se houver uma relação não linear entre as variáveis, a correlação linear não será uma medida apropriada para avaliar essa relação.
#
# ---

# %% [markdown]
# > 🛠️ *Exemplo prático 5:* Calculando a correlação entre diferentes moedas

# %%
# Matriz de correlação
df_cambio.corr()
# Out:
#           BRL       CAD       CHF       GBP
# BRL  1.000000  0.458610  0.250595 -0.390891
# CAD  0.458610  1.000000  0.359266 -0.413612
# CHF  0.250595  0.359266  1.000000 -0.742034
# GBP -0.390891 -0.413612 -0.742034  1.000000

# %% [markdown]
# 💬 Note que a matriz de correlação representa numericamente o gráfico de dispersão conjunto!

# %%
# Criando o gráfico
pd.plotting.scatter_matrix(df_cambio)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ---
#
# > 🛠️ *Exemplo prático 6:* Calculando a correlação entre a inflação dos países que compõe o BRICS

# %%
# Matriz de correlação
df_fred.corr()
# Out:
#                  Brasil    Russia     Índia     China  África do Sul
# Brasil         1.000000  0.478766 -0.247979 -0.286648       0.143931
# Russia         0.478766  1.000000 -0.234471 -0.314344       0.233931
# Índia         -0.247979 -0.234471  1.000000  0.291512       0.247575
# China         -0.286648 -0.314344  0.291512  1.000000      -0.099074
# África do Sul  0.143931  0.233931  0.247575 -0.099074       1.000000

# %%
# Criando o gráfico
pd.plotting.scatter_matrix(df_fred)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Correlação NÃO implica causalidade
#
# ⛔ *'A correlação não implica causalidade'* é um princípio fundamental que enfatiza que o fato de duas variáveis estarem correlacionadas (ou seja, apresentarem uma relação estatística) não significa automaticamente que uma **causa** a outra. Essa é uma importante ressalva a ser considerada ao interpretar resultados de estudos e análises estatísticas!
#
# > 🧠 Portanto, é fundamental ter cautela ao interpretar correlações e não assumir automaticamente uma relação de causa e efeito com base na correlação observada. Estabelecer a causalidade requer evidências adicionais, muitas vezes obtidas por meio de experimentos controlados ou análises mais complexas que levam em consideração outras variáveis potenciais.
